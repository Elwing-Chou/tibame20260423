# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20260423/blob/main/tibame20260423.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. jupyter notebok使用的筆記: markdown語法
#
# 2. colab是一個線上版本的jupyter notebook
#
# 3. 一個完整的python程式應該會以.py作為結尾(從第一行到最後一行)
#
# 4. 一個練習的jupyter notebook會以.ipynb作為結尾
#
# 5. 支援特殊語法: Latex Math
#
# $ Area = \frac {1}{2} \pi R^2 $
